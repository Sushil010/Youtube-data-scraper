# %%
from googleapiclient.discovery import build

# %%
# !pip install --upgrade google-api-python-client
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.0/13.0 MB 26.3 MB/s eta 0:00:00
# ...
#   Attempting uninstall: google-api-python-client
#     Found existing installation: google-api-python-client 2.84.0
#     Uninstalling google-api-python-client-2.84.0:
#       Successfully uninstalled google-api-python-client-2.84.0
# ...

# %%
api_key='AIzaSyAcKIno7KiqWLGwthNK5cz4k7uj-3cxA4I'
channel_id=['UCX6OQ3DkcsbYNE6H8uQQuVA',
            'UCnz-ZXXER4jOvuED5trXfEA',
            'UC3S6nIDGJ5OtpC-mbvFA8Ew',
            'UC0Kv7pGGkFHzVWCLTZkhfWg'
            ]
#channel_id='UCnz-ZXXER4jOvuED5trXfEA'

# %%
api_key='AIzaSyAcKIno7KiqWLGwthNK5cz4k7uj-3cxA4I'
youtube=build('youtube','v3',developerKey=api_key)

# %%
def channel_stats(youtube, channel_id):
  final_list=[]
  request = youtube.channels().list(
      part='snippet,contentDetails,statistics',
      id=','.join(channel_id)
    )
  response = request.execute()

  for item_count in range(len(channel_id)):
    data=dict(channel_name = response['items'][item_count]['snippet']['title'],
            Subscribers= response['items'][item_count]['statistics']['subscriberCount'],
            Views = response['items'][item_count]['statistics']['viewCount'],
            Total_videos = response['items'][item_count]['statistics']['videoCount']
            )
    final_list.append(data)
  return(final_list)

# %%
df1=channel_stats(youtube,channel_id)

# %%
import pandas as pd

# %%
df=pd.DataFrame(df1)

# %%
df
# Out:
#           channel_name Subscribers        Views Total_videos
# 0           Noud Neefs           7           56            5
# 1  Orange Juice Gaming     3070000   1506466802         2389
# 2              MrBeast   225000000  40107049232          774
# 3              techTFQ      258000     13632237          100

# %%
#chanl_id='UC3S6nIDGJ5OtpC-mbvFA8Ew'

# %%
def channel_stats(youtube, channel_id):
  final_list=[]
  request = youtube.videos().list(
      part='snippet,contentDetails,statistics',
      id=','.join(channel_id)
      #id='chanl_id'
    )
  response=request.execute()
  return(response)

# %%
channel_stats(youtube,channel_id)
# Out:
# {'kind': 'youtube#videoListResponse',
#  'etag': 'YIUPVpqNjppyCWOZfL-19bLb7uk',
#  'items': [],
#  'pageInfo': {'totalResults': 0, 'resultsPerPage': 0}}

# %%
def channel_video_stats(youtube, channel_id):
    video_stats = []


    playlist_request = youtube.channels().list(
        part='contentDetails',
        id=channel_id
    )
    playlist_response = playlist_request.execute()
    return(playlist_response)

# %%
channel_video_stats(youtube,channel_id)
# Out:
# {'kind': 'youtube#channelListResponse',
#  'etag': '0eFN-lLBmf_JwqSDP6g_BSOzbWc',
#  'pageInfo': {'totalResults': 4, 'resultsPerPage': 5},
#  'items': [{'kind': 'youtube#channel',
#    'etag': 'AKZVXBn6y2MmlmNxLB28WjTRLgw',
#    'id': 'UC3S6nIDGJ5OtpC-mbvFA8Ew',
#    'contentDetails': {'relatedPlaylists': {'likes': '',
#      'uploads': 'UU3S6nIDGJ5OtpC-mbvFA8Ew'}}},
#   {'kind': 'youtube#channel',
#    'etag': 'aAYPzCKZ8ZkEyOmvO4q1kS5kKBo',
#    'id': 'UC0Kv7pGGkFHzVWCLTZkhfWg',
#    'contentDetails': {'relatedPlaylists': {'likes': '',
#      'uploads': 'UU0Kv7pGGkFHzVWCLTZkhfWg'}}},
#   {'kind': 'youtube#channel',
#    'etag': '-f8h6RTCebSZttPcDz3dTkMV5yo',
#    'id': 'UCX6OQ3DkcsbYNE6H8uQQuVA',
#    'contentDetails': {'relatedPlaylists': {'likes': '',
#      'uploads': 'UUX6OQ3DkcsbYNE6H8uQQuVA'}}},
#   {'kind': 'youtube#channel',
#    'etag': 'z66xiJYCnen_otPgDnaWUeCiRpw',
#    'id': 'UCnz-ZXXER4jOvuED5trXfEA',
#    'contentDetails': {'relatedPlaylists': {'likes': '',
# ...

# %%
def channel_video_stats(youtube, channel_id):
  uploads_playlist_id='UU3S6nIDGJ5OtpC-mbvFA8Ew'
  playlist_items_request = youtube.playlistItems().list(
              part='snippet',
              playlistId=uploads_playlist_id,
              maxResults=50
          )
  playlist_items_response = playlist_items_request.execute()
  return(playlist_items_response)

# %%
channel_video_stats(youtube,channel_id)
# Out:
# {'kind': 'youtube#playlistItemListResponse',
#  'etag': 'keOYEAeJ3AAsWJnLX6KprdW6-d8',
#  'nextPageToken': 'EAAafVBUOkNESWlFREpFUkRZd1JrWTVOemswTVVGRlFVSW9BVWlSNktTdGxMMkRBMUFCV2pnaVEyaG9WbFpVVGxST2JUVktVa1ZrUzA1Vk9UQmpSVTEwWWxkS01sSnJSVFJTV0dOVFJFRnFYelE0ZVhOQ2FFUnZNazlxTkVGUkln',
#  'items': [{'kind': 'youtube#playlistItem',
#    'etag': 'ejsrGQfkqJ-cBHMB3bVKX5R6dIs',
#    'id': 'VVUzUzZuSURHSjVPdHBDLW1idkZBOEV3LlhaYU10U1JuQ0Rv',
#    'snippet': {'publishedAt': '2024-01-01T21:43:20Z',
#     'channelId': 'UC3S6nIDGJ5OtpC-mbvFA8Ew',
#     'title': 'Cannoneer is Rock/Paper/Scissors',
# ...

# %%
def channel_video_stats(youtube, channel_id):
    video_stats = []


    playlist_request = youtube.channels().list(
        part='snippet,contentDetails,statistics',
        id=channel_id
    )
    playlist_response = playlist_request.execute()
    Total_videos = playlist_response['items'][0]['statistics']['videoCount']
    if playlist_response['items']:
        uploads_playlist_id = playlist_response['items'][0]['contentDetails']['relatedPlaylists']['uploads']

        playlist_items_request = youtube.playlistItems().list(
            part='snippet',
            playlistId=uploads_playlist_id,
            maxResults=Total_videos
        )
        playlist_items_response = playlist_items_request.execute()

        if playlist_items_response['items']:
            for item in playlist_items_response['items']:
                video_id = item['snippet']['resourceId']['videoId']

                video_request = youtube.videos().list(
                    part='snippet,statistics',
                    id=video_id
                )
                video_response = video_request.execute()

                if video_response['items']:
                    video_info = {
                        'title': video_response['items'][0]['snippet']['title'],
                        'views': video_response['items'][0]['statistics']['viewCount'],
                        'likes': video_response['items'][0]['statistics']['likeCount'],
                    }
                    video_stats.append(video_info)

    return (video_stats)

channel_id = 'UC3S6nIDGJ5OtpC-mbvFA8Ew'


channel_video_statistics = channel_video_stats(youtube, channel_id)

# %%
def get_channel_id_by_name(youtube, channel_name):
    search_response = youtube.search().list(
        q=channel_name,
        part='id',
        type='channel',
        maxResults=1
    ).execute()

    if search_response.get('items'):
        channel_id = search_response['items'][0]['id']['channelId']
        return channel_id
    else:
        return None


def channel_video_stats(youtube, channel_id):
    video_stats = []

    playlist_request = youtube.channels().list(
        part='snippet,contentDetails,statistics',
        id=channel_id
    )
    playlist_response = playlist_request.execute()
    Total_videos = playlist_response['items'][0]['statistics']['videoCount']
    if playlist_response['items']:
        uploads_playlist_id = playlist_response['items'][0]['contentDetails']['relatedPlaylists']['uploads']
        next_page_token = None

        while True:
            playlist_items_request = youtube.playlistItems().list(
                part='snippet',
                playlistId=uploads_playlist_id,
                maxResults=50,
                pageToken=next_page_token
            )
            playlist_items_response = playlist_items_request.execute()

            if playlist_items_response['items']:
                for item in playlist_items_response['items']:
                    video_id = item['snippet']['resourceId']['videoId']

                    video_request = youtube.videos().list(
                        part='snippet,statistics',
                        id=video_id
                    )
                    video_response = video_request.execute()

                    if video_response['items']:
                        video_item = video_response['items'][0]
                        video_info = {
                            'title': video_response['items'][0]['snippet']['title'],
                            'views': video_response['items'][0]['statistics']['viewCount'],
                            'likes': video_response['items'][0]['statistics']['likeCount'] if 'likeCount' in video_item['statistics'] else 0,
                        }
                        video_stats.append(video_info)


                next_page_token = playlist_items_response.get('nextPageToken')

                if not next_page_token:
                    break
            else:
                break

    return video_stats


api_key='AIzaSyAcKIno7KiqWLGwthNK5cz4k7uj-3cxA4I'
youtube=build('youtube','v3',developerKey=api_key)
channel_name=input("Enter channel name: ")
channel_id = get_channel_id_by_name(youtube,channel_name)
if channel_id is None:
  print("Invalid Channel Name")
else:
  channel_video_statistics = channel_video_stats(youtube, channel_id)

df1=pd.DataFrame(channel_video_statistics)
df1
# Out:
# Enter channel name: gloo
#                                        title   views likes
# 0                              Gloo-Want You  219051  8242
# 1  Gloo-MSN!(Make Some Noise!)(Feat.42Chill)  156430  5285
# 2                 Gloo-FTS!(Fxxk That Sxxt!)   97663  4304
# 3                          Gloo - INTRO:GLOO   89253  4157

# %%
def get_channel_id_by_name(youtube, channel_name):
    search_response = youtube.search().list(
        q=channel_name,
        part='id',
        type='channel',
        maxResults=1
    ).execute()

    if search_response.get('items'):
        channel_id = search_response['items'][0]['id']['channelId']
        return channel_id
    else:
        return None

# %%
op
# Out:
# 'Invalid Channel Name'

# %%
channel_video_statistics
# Out:
# [{'title': 'Iklan Charm - JKT48 Melody, Nabilah, Haruka (2014)',
#   'views': '18931',
#   'likes': '128'},
#  {'title': 'Iklan Charm Night - JKT48 (2015)', 'views': '8543', 'likes': '52'},
#  {'title': 'Iklan Charm - JKT48 Charm Rescue Team Bioskop (2014)',
#   'views': '12247',
#   'likes': '66'},
#  {'title': 'Iklan Charm - Charm Girls JKT48 (2013)',
#   'views': '39272',
#   'likes': '165'},
#  {'title': 'Iklan Lip Ice - JKT48', 'views': '6235', 'likes': '37'},
#  {'title': 'Iklan Lip Ice Sheer Color - JKT48',
#   'views': '33274',
#   'likes': '139'},
#  {'title': 'Iklan OXY - JKT48', 'views': '6945', 'likes': '42'},
#  {'title': 'Iklan Tolak Angin - JKT48 (2014)',
#   'views': '25035',
#   'likes': '153'},
#  {'title': 'Iklan Tolak Angin Cair - JKT48 (2014)',
#   'views': '5375',
#   'likes': '33'},
#  {'title': 'Iklan IM3 - SMS Suka Suka JKT48', 'views': '4783', 'likes': '33'},
#  {'title': 'Iklan IM3 Play - JKT48 dan Caesar',
#   'views': '14991',
#   'likes': '94'},
# ...

# %%
df1=pd.DataFrame(channel_video_statistics)

# %%
df1
# Out:
#                                                 title  views likes
# 0   Iklan Charm - JKT48 Melody, Nabilah, Haruka (2...  18931   128
# 1                    Iklan Charm Night - JKT48 (2015)   8543    52
# 2   Iklan Charm - JKT48 Charm Rescue Team Bioskop ...  12247    66
# 3              Iklan Charm - Charm Girls JKT48 (2013)  39272   165
# 4                               Iklan Lip Ice - JKT48   6235    37
# ..                                                ...    ...   ...
# 90  JKT48 dan Pocari Sweat - Heavy Rotation Full V...  54127   702
# 91  Pocari Sweat - "Kembalikan IONmu" Ryutaro Maki...  21115   120
# 92  Pocari Sweat - Youth Sweat Beautiful Aelke Mar...   2148    18
# 93  Pocari Sweat  - Youth Sweat Beautiful (Drama) ...   3028    20
# 94              Pocari Sweat Ramadhan - Kaktus (2016)   4749    15
#
# [95 rows x 3 columns]

# %%
import tkinter as tk
from tkinter import messagebox
import pandas as pd
from googleapiclient.discovery import build

def get_channel_id_by_name(youtube, channel_name):
    search_response = youtube.search().list(
        q=channel_name,
        part='id',
        type='channel',
        maxResults=1
    ).execute()

    if search_response.get('items'):
        channel_id = search_response['items'][0]['id']['channelId']
        return channel_id
    else:
        return None

def channel_video_stats(youtube, channel_id):
    video_stats = []

    playlist_request = youtube.channels().list(
        part='snippet,contentDetails,statistics',
        id=channel_id
    )
    playlist_response = playlist_request.execute()
    Total_videos = playlist_response['items'][0]['statistics']['videoCount']
    if playlist_response['items']:
        uploads_playlist_id = playlist_response['items'][0]['contentDetails']['relatedPlaylists']['uploads']
        next_page_token = None

        while True:
            playlist_items_request = youtube.playlistItems().list(
                part='snippet',
                playlistId=uploads_playlist_id,
                maxResults=50,
                pageToken=next_page_token
            )
            playlist_items_response = playlist_items_request.execute()

            if playlist_items_response['items']:
                for item in playlist_items_response['items']:
                    video_id = item['snippet']['resourceId']['videoId']

                    video_request = youtube.videos().list(
                        part='snippet,statistics',
                        id=video_id
                    )
                    video_response = video_request.execute()

                    if video_response['items']:
                        video_item = video_response['items'][0]
                        video_info = {
                            'title': video_response['items'][0]['snippet']['title'],
                            'views': video_response['items'][0]['statistics']['viewCount'],
                            'likes': video_response['items'][0]['statistics']['likeCount'] if 'likeCount' in video_item['statistics'] else 0,
                        }
                        video_stats.append(video_info)


                next_page_token = playlist_items_response.get('nextPageToken')

                if not next_page_token:
                    break
            else:
                break

    return video_stats


def fetch_channel_stats():
    channel_name = entry.get()
    api_key='AIzaSyAcKIno7KiqWLGwthNK5cz4k7uj-3cxA4I'
    youtube=build('youtube','v3',developerKey=api_key)
    channel_id = get_channel_id_by_name(youtube, channel_name)

    if channel_id is None:
        messagebox.showerror("Error", "Invalid channel name")
    else:
        stats = channel_video_stats(youtube, channel_id)
        if not stats:
            messagebox.showinfo("Info", "No video statistics found for this channel")
        else:
            df = pd.DataFrame(stats)
            output_text.config(state='normal')
            output_text.delete('1.0', tk.END)  # Clear previous output
            output_text.insert(tk.END, df.to_string(index=False))
            output_text.config(state='disabled')

root = tk.Tk()
root.title("YouTube Channel Video Stats")

label = tk.Label(root, text="Enter YouTube Channel Name:")
label.pack()

entry = tk.Entry(root)
entry.pack()

button = tk.Button(root, text="Fetch Stats", command=fetch_channel_stats)
button.pack()

output_text = tk.Text(root, height=20, width=80)
output_text.pack()
output_text.config(state='disabled')  # Make output text read-only

youtube = build('youtube', 'v3', developerKey='YOUR_API_KEY')  # Replace 'YOUR_API_KEY' with your actual API key

root.mainloop()
# Out:
# ---------------------------------------------------------------------------
# TclError                                  Traceback (most recent call last)
# <ipython-input-77-8e94bb89b464> in <cell line: 89>()
#      87             output_text.config(state='disabled')
#      88
# ---> 89 root = tk.Tk()
#      90 root.title("YouTube Channel Video Stats")
#      91
#
# /usr/lib/python3.10/tkinter/__init__.py in __init__(self, screenName, baseName, className, useTk, sync, use)
#    2297                 baseName = baseName + ext
#    2298         interactive = False
# -> 2299         self.tk = _tkinter.create(screenName, baseName, className, interactive, wantobjects, useTk, sync, use)
#    2300         if useTk:
#    2301             self._loadtk()
#
# TclError: no display name and no $DISPLAY environment variable

# %%
import tkinter as tk
